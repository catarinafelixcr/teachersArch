# %%
import pandas as pd

# %%
df = pd.read_csv("student_metrics.csv")
df
# Out:
#                   student  total_commits  avg_lines_per_commit  active_days  \
# 0               ZePedross             36             69.250000           11
# 1         diogojgferreira             43             48.953488           10
# 2    oliveira-andre-unilu            124           1480.500000           41
# 3           Andre Martins             46           8807.717391           19
# 4           Diogo Martins             20             97.950000            2
# ..                    ...            ...                   ...          ...
# 432          Rafael Faria              0              0.000000            0
# 433           Pedro Biain              0              0.000000            0
# 434                   B T              0              0.000000            0
# 435            João Silva              0              0.000000            0
# 436          Alice Khalil              0              0.000000            0
#
# ...
